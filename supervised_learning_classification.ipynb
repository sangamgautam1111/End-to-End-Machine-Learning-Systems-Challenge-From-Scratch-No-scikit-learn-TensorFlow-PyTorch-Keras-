# %%
#since we are at supervised learning lets understand what is classification? 
#what is classification in terms of machine learning  > classification is a supervised learning task where the goal is to predict the class or category of the input data.
#means the ouput dependent variable will always be categorical value

# %%
#logicstic  regression = a ml model used to predict the probability of a certain outcome or class or to predict categorical values
#application of the model:
# spam detection (logistic regression is also used to detect spam emails)
#how ? = > we will use the logistic regression model to predict the probability of an email being spam or not spam.since spam is categroical dependent variable
# second application : predicting whether a customer is likely to buy a product or not, we can use logistic regression to predict the probability of a customer buying a product.
# third application : predicting whether a customer is likely to churn or not, we can use logistic regression to predict the probability of a customer churning.
#what is churn ? = > churn is when a customer stops using a service or product.
#common pattern : it is widely being used in producting categorical values or dependent variables
#what is categorical => a categorical variable is a variable that has a limited number of possible values or categories.
#common question = > can categrorical values be predicted by machine learning models? = > yes, categorical values can be predicted by machine learning models.
#categorical values means the set of words that are used to describe something or the set of classes that a variable can take on.
#What to understand about categorical value ? = > categorical value is a value that can take on a limited number of possible values or categories.
#Examples:
#Gender: Male, Female
#Job Title: Manager, Engineer, Salesperson
#Education Level: Bachelor's, Master's, Doctorate
#Common qs : can we say categorical value is set of words dividing categories ? = > yes, categorical value is a set of words that are used to describe something or the set of classes that a variable can take on.

# %%
#types of logistic regression
#1. binary classification
#2. multi-class classification
#3. multi-label classification
#common qs: does logistic regression is different model than binary classification or multi class classification or multi label ? = > yes, logistic regression is a supervised learning model that is used to predict the probability of a categorical outcome.
#the key difference is #1. binary classification #2. multi-class classification #3. multi-label classification were made from logistic regression.
#common confusion if logistic regression predicts categorical values then why it (regressiom - models used to predict continous values) and it is in classification model why how ?  = Logistic regression is named for its regression-like equation, but it’s used for classification because it predicts probabilities that are converted into categorical outcomes.

# %%
#lets start with logistic regression
#equation and derivation of equation 
#how to use model using sklearn nad tensorflow pytorch keras
#scratch implementation using python -> numpy
#use cases with datasets -> spam detection, customer churn prediction
#when to use model brief overview
#training implemented model on many dataset and evaluating performance
#tradeoffs and limitations
#its types 
#interview question asked in interview of maang company
#conclusion

# %%
#sigmoid Function = > sigmoid function is meant by a function or equation which is trying to take independent variable x and convert it into prrobabilty of 0 and 1 with respect to dependent variable y.
#sigmoid function can be understand by function tha tis used to predict the probability of class or categorical dependent variable which is 0 or 1 
#why 0 or 1 ? = > 0 means not spam and 1 means spam in the case of spam detection
#what actually 0 and 1 means it seprates the dependent variable into two categories or classes 
#which line divides the classes = > the line that divides the classes is called the decision boundary.
#decision boundary is formed by logistic regression model

# %%
#sigmoid function = y = 1 / (1 + e^-x) 
#does the feature is really is in negative  = > yes
#quick view : how the feature x is calculated x = weightw1 * featurex1 + weightw2 * featurex2 + biasb
